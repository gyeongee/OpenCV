# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.174-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached ultralytics-8.3.174-py3-none-any.whl (1.0 MB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 9.2 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 9.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.6 MB/s eta 0:00:00
# ...
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# ...

# %%
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.2.3-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.2.3-py3-none-any.whl (86 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.9 MB 11.8 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.9 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.0 MB/s eta 0:00:00
# ...

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\opencv\\자동차감지'

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO model
model = YOLO("./best (1).pt")

# Open the video file
video_path = "./ASMR _ KOREA DRIVE _ 4K Highway Driving Ambience 2023 Seoul to Incheon.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 326.4ms
# Speed: 7.3ms preprocess, 326.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 25
#      22 annotated_frame = results[0].plot()
#      24 # Display the annotated frame
# ---> 25 cv2.imshow("YOLO Inference", annotated_frame)
#      27 # Break the loop if 'q' is pressed
#      28 if cv2.waitKey(1) & 0xFF == ord("q"):
#
# File ~\anaconda3\Lib\site-packages\ultralytics\utils\patches.py:89, in imshow(winname, mat)
#      71 def imshow(winname: str, mat: np.ndarray) -> None:
#      72     """
#      73     Display an image in the specified window with multilanguage window name support.
#      74
#    (...)
#      87         >>> imshow("Example Window", img)  # Display the image
#      88     """
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# YOLO 결과 이미지가 ndarray 형태라고 가정
annotated_frame = results[0].plot()

# OpenCV는 BGR → Matplotlib는 RGB
annotated_frame_rgb = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

# Jupyter용 시각화
plt.imshow(annotated_frame_rgb)
plt.axis("off")
plt.title("YOLO Inference")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load the YOLO model
model = YOLO("./best (1).pt")

# Open the video file
video_path = "./ASMR _ KOREA DRIVE _ 4K Highway Driving Ambience 2023 Seoul to Incheon.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
frame_count = 0
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    frame_count += 1

    # 프레임 수를 줄이기 위해 예: 5프레임에 1개만 처리
    if frame_count % 5 != 0:
        continue

    # Run YOLO inference
    results = model(frame)

    # 결과 시각화
    annotated_frame = results[0].plot()
    annotated_frame_rgb = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

    # Jupyter에서 시각화
    plt.imshow(annotated_frame_rgb)
    plt.axis("off")
    plt.title(f"YOLO Inference - Frame {frame_count}")
    plt.show()

    # 아래 코드는 Jupyter에선 필요 없음, 실시간이 아니니까
    # if cv2.waitKey(1) & 0xFF == ord("q"):
    #     break

cap.release()
# Out:
# 0: 384x640 (no detections), 174.2ms
# Speed: 5.3ms preprocess, 174.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
